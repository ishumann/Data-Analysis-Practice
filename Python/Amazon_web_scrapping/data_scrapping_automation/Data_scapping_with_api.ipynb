# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

# %%
url = "https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest"
parameters = {"start": "1", "limit": "5000", "convert": "USD"}
headers = {
    "Accepts": "application/json",
    "X-CMC_PRO_API_KEY": "30289423-4923-43f4-9d13-4fd06319afac",
}

session = Session()
session.headers.update(headers)

try:
    response = session.get(url, params=parameters)
    data = json.loads(response.text)
    print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
    print(e)


# 30289423-4923-43f4-9d13-4fd06319afac
# Out:
# {'status': {'timestamp': '2025-05-22T07:36:50.404Z', 'error_code': 0, 'error_message': None, 'elapsed': 2, 'credit_count': 1, 'notice': None}, 'data': [{'id': 5894, 'name': '6fu1jw3xy59', 'symbol': 'o8wkyuxf4vb', 'slug': 'hxzq9idyfb4', 'cmc_rank': 4954, 'num_market_pairs': 6910, 'circulating_supply': 4578, 'total_supply': 9168, 'max_supply': 3059, 'infinite_supply': None, 'last_updated': '2025-05-22T07:36:50.403Z', 'date_added': '2025-05-22T07:36:50.403Z', 'tags': ['7vp70j4x0ig', 'fxza0atlcxq', 'qmtiiw8e94h', 'mlu33awxi0n', 'bxanrs3i3qq', 'a9d727cpsba', '6kztv1s62yf', '11t4jj7wn4xr', 'tru4j2jawe', 'w3rzo597jr'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.40493801998611145, 'volume_24h': 8467, 'volume_change_24h': 0.5789056026248698, 'percent_change_1h': 0.33077074230870473, 'percent_change_24h': 0.7350782736616193, 'percent_change_7d': 0.1054357227382301, 'market_cap': 0.3740482298054495, 'market_cap_dominance': 4672, 'fully_diluted_market_cap': 0.49976972846709367, 'last_updated': '2025-05-22T07:36:50.403Z'}}}, {'id': 2571, 'name': '9vw5nazp4x', 'symbol': 'v5l10s5l5d', 'slug': 'z35p9rjljwh', 'cmc_rank': 8567, 'num_market_pairs': 6006, 'circulating_supply': 3332, 'total_supply': 5389, 'max_supply': 9195, 'infinite_supply': None, 'last_updated': '2025-05-22T07:36:50.403Z', 'date_added': '2025-05-22T07:36:50.403Z', 'tags': ['lbek4m8w93j', 'v40vhx1oqga', 'rrg9n0tku9', 'bqcgtbf59hb', 'rgyb8wt1xbi', 'mvss0djvio8', '9toim3mp8cd', 'e9odcvrahjp', 'stbt9yhr1ha', 'h7lqnp1cpmj'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.5682256407835056, 'volume_24h': 7688, 'volume_change_24h': 0.34802079792643004, 'percent_change_1h': 0.7625596965476265, 'percent_change_24h': 0.38895344440748003, 'percent_change_7d': 0.7456214568886936, 'market_cap': 0.18143200269198245, 'market_cap_dominance': 6986, 'fully_diluted_market_cap': 0.22522445256226264, 'last_updated': '2025-05-22T07:36:50.403Z'}}}, {'id': 2428, 'name': 'ldemuxo76eg', 'symbol': 'uvsa0my0j7k', 'slug': '3fsh0ime4ph', 'cmc_rank': 4964, 'num_market_pairs': 3584, 'circulating_supply': 2779, 'total_supply': 7479, 'max_supply': 4514, 'infinite_supply': None, 'last_updated': '2025-05-22T07:36:50.403Z', 'date_added': '2025-05-22T07:36:50.403Z', 'tags': ['p5kteopn32', 'b8wskx918fj', '3yxdp2weejf', 'up4laxowzy', '61egkesfuow', 'mlrvza5yl8j', 'fvphoecwej', 'nhih7cd4gm', 'dxadadm70vm', 'tfth6mectb7'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.6836143868800262, 'volume_24h': 3711, 'volume_change_24h': 0.36490007369840205, 'percent_change_1h': 0.0732224065946816, 'percent_change_24h': 0.38413431379402696, 'percent_change_7d': 0.8168843546727182, 'market_cap': 0.3809238461791804, 'market_cap_dominance': 2452, 'fully_diluted_market_cap': 0.4704959575074763, 'last_updated': '2025-05-22T07:36:50.403Z'}}}, {'id': 9041, 'name': '2y4xms3266f', 'symbol': 'hccixmh1hde', 'slug': '2ts1o4cp91', 'cmc_rank': 9089, 'num_market_pairs': 3055, 'circulating_supply': 2095, 'total_supply': 1465, 'max_supply': 2578, 'infinite_supply': None, 'last_updated': '2025-05-22T07:36:50.403Z', 'date_added': '2025-05-22T07:36:50.403Z', 'tags': ['wm0wt47f6g8', '175bt1z18qn', '6rq6fqureh3', '32j8lufb89v', '6gisw2gdtm4', 'r0ogdxaa1hi', 'henw4nkjdgj', '07t7d34bqo2v', '7hdzu2iuihp', 'ud2ijrc6gcl'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.6513851006112541, 'volume_24h': 4244, 'volume_change_24h': 0.31270284690260053, 'percent_change_1h': 0.46841124224115904, 'percent_change_24h': 0.8110335955779078, 'percent_change_7d': 0.7071108880687498, 'market_cap': 0.5572138970009153, 'market_cap_dominance': 156, 'fully_diluted_market_cap': 0.9692121098108106, 'last_updated': '2025-05-22T07:36:50.403Z'}}}, {'id': 9193, 'name': 'zohakpny ...

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd



pd.set_option("display.max_columns", None)

# %%
df = pd.DataFrame(data["data"])

# %%
def api_runner():
    global df
    url = "https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest"
    parameters = {"start": "1", "limit": "5000", "convert": "USD"}
    headers = {
        "Accepts": "application/json",
        "X-CMC_PRO_API_KEY": "30289423-4923-43f4-9d13-4fd06319afac",
    }

    session = Session()
    session.headers.update(headers)

    session = Session()
    session.headers.update(headers)

    try:
        response = session.get(url, params=parameters)
        data = json.loads(response.text)
        # print(data)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
        print(e)

    # NOTE:
    # I had to go in and put "jupyter notebook --NotebookApp.iopub_data_rate_limit=1e10"
    # Into the Anaconda Prompt to change this to allow to pull data

    # Use this if you just want to keep it in a dataframe
    df2 = pd.json_normalize(data["data"])
    df2["Timestamp"] = pd.to_datetime("now")
    df = pd.concat([df, df2], ignore_index=True)
    # Use this if you want to create a csv and append data to it
    # df = pd.json_normalize(data['data'])
    # df['timestamp'] = pd.to_datetime('now')
    # df

    # if not os.path.isfile(r'C:\Users\alexf\OneDrive\Documents\Python Scripts\API.csv'):
    # df.to_csv(r'C:\Users\alexf\OneDrive\Documents\Python Scripts\API.csv', header='column_names')
    # else:
    # df.to_csv(r'C:\Users\alexf\OneDrive\Documents\Python Scripts\API.csv', mode='a', header=False)

    # Then to read in the file: df = pd.read_csv(r'C:\Users\alexf\OneDrive\Documents\Python Scripts\API.csv')


# If that didn't work try using the local host URL as shown in the video

# %%
import os
from time import time
from time import sleep

for i in range(3):
    api_runner()
    print("API Runner completed")
    sleep(1)  # sleep for 1 minute
exit()
# Out:
# API Runner completed
# API Runner completed
# API Runner completed

# %%
df
# Out:
#       id         name       symbol         slug  cmc_rank  num_market_pairs  \
# 10  5894  6fu1jw3xy59  o8wkyuxf4vb  hxzq9idyfb4      4954              6910
# 11  2571   9vw5nazp4x   v5l10s5l5d  z35p9rjljwh      8567              6006
# 12  2428  ldemuxo76eg  uvsa0my0j7k  3fsh0ime4ph      4964              3584
# 13  9041  2y4xms3266f  hccixmh1hde   2ts1o4cp91      9089              3055
# 14  9193  zohakpny3km   8nnysyrmnt  8qtnsa0ht4x      1334              7111
# 15  8510  c7bkbh5lq1j  d5bzuka532o   okyx453ig2      8908              8147
# 16  8864  luiip6kb98e  2qhhucr57lj  fixw00fsmzk      2459              2458
# 17  7075  fdzvbsl5y1q  4c10mjfgptq  sm4ei4dkrcq      4350              7602
# 18  2032  ademf52ykok   i5oc3e8e2u  9shhjrhjz8u      3442              3539
# 19  7077  umuacnv88rp   ne3av8ij84  4m4ei08vybw        35              4174
#
#     circulating_supply  total_supply  max_supply infinite_supply  \
# 10                4578          9168        3059            None
# 11                3332          5389        9195            None
# 12                2779          7479        4514            None
# 13                2095          1465        2578            None
# 14                8003          6138        3514            None
# 15                5697          9256        5316            None
# 16                5409          2824        8372            None
# 17                1469          5909        9456            None
# 18                6934          8501        1909            None
# 19                7682          2159        2621            None
#
#                 last_updated                date_added  \
# 10  2025-05-22T07:36:50.403Z  2025-05-22T07:36:50.403Z
# 11  2025-05-22T07:36:50.403Z  2025-05-22T07:36:50.403Z
# 12  2025-05-22T07:36:50.403Z  2025-05-22T07:36:50.403Z
# 13  2025-05-22T07:36:50.403Z  2025-05-22T07:36:50.403Z
# 14  2025-05-22T07:36:50.403Z  2025-05-22T07:36:50.403Z
# 15  2025-05-22T07:36:50.403Z  2025-05-22T07:36:50.403Z
# 16  2025-05-22T07:36:50.404Z  2025-05-22T07:36:50.404Z
# 17  2025-05-22T07:36:50.404Z  2025-05-22T07:36:50.404Z
# 18  2025-05-22T07:36:50.404Z  2025-05-22T07:36:50.404Z
# 19  2025-05-22T07:36:50.404Z  2025-05-22T07:36:50.404Z
#
#                                                  tags platform  \
# 10  [7vp70j4x0ig, fxza0atlcxq, qmtiiw8e94h, mlu33a...     None
# 11  [lbek4m8w93j, v40vhx1oqga, rrg9n0tku9, bqcgtbf...     None
# 12  [p5kteopn32, b8wskx918fj, 3yxdp2weejf, up4laxo...     None
# 13  [wm0wt47f6g8, 175bt1z18qn, 6rq6fqureh3, 32j8lu...     None
# 14  [xlw1rhzgf0k, rdm16t0tyy, evd07gexngo, 3kxdlfv...     None
# 15  [8fohde7dfjw, mn59c4ptnn, 92eywgyuobu, dywmtbg...     None
# 16  [u5b3hdblxm, 6fs31a0h5w6, kbt76xumwzc, 1u94drb...     None
# 17  [yan7msg68, 9frx40y2z6q, 9yw0l9y4le, t63p4fpaa...     None
# 18  [eitdixu5m0l, ejfsd2sv535, k8bfijbc89k, qp4ayn...     None
# 19  [aox3owkgr8p, d9lizcpjz3, q6p03f0fwz, i01fxqcz...     None
#
#    self_reported_circulating_supply self_reported_market_cap quote  \
# 10                             None                     None   NaN
# 11                             None                     None   NaN
# 12                             None                     None   NaN
# 13                             None                     None   NaN
# 14                             None                     None   NaN
# 15                             None                     None   NaN
# 16                             None                     None   NaN
# 17                             None                     None   NaN
# 18                             None                     None   NaN
# 19                             None                     None   NaN
#
#     quote.USD.price  quote.USD.volume_24h  quote.USD.volume_change_24h  \
# 10         0.404938                8467.0                     0.578906
# 11         0.568226                7688.0                     0.348021
# 12         0.683614                3711.0                     0.364900
# 13         0.651385                4244.0                     0.312703
# 14         0.078244                1694.0                     0.255468
# 15         0.511186                2758.0                     0.536126
# 16         0.751175                8311.0                     0.370474
# 17         0.849991                6893.0                     0.523420
# 18         0.314051                8317.0                     0.563989
# 19         0.975468                6925.0                     0.487086
#
#     quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# 10                     0.330771                      0.735078
# 11                     0.762560                      0.388953
# 12                     0.073222                      0.384134
# 13                     0.468411                      0.811034
# 14                     0.566584                      0.209495
# 15                     0.040629                      0.692577
# 16                     0.453210                      0.640235
# 17                     0.071002                      0.679276
# 18                     0.482958                      0.779002
# 19                     0.873291                      0.214338
#
#     quote.USD.percent_change_7d  quote.USD.market_cap  \
# 10                     0.105436              0.374048
# 11                     0.745621              0.181432
# 12                     0.816884              0.380924
# 13                     0.707111              0.557214
# 14                     0.154240              0.523743
# 15                     0.012384              0.889666
# 16                     0.262351              0.173277
# 17                     0.971208              0.322800
# 18                     0.187622              0.009592
# 19                     0.872360              0.762629
#
#     quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 10                          4672.0                            0.499770
# 11                          6986.0                            0.225224
# 12                          2452.0                            0.470496
# 13                           156.0                            0.969212
# 14                          9377.0                            0.749157
# 15                          5128.0                            0.917607
# 16                           494.0                            0.366891
# 17                          3690.0                            0.868019
# 18                          2297.0                            0.718257
# 19                          4206.0                            0.710699
#
#       quote.USD.last_updated                  Timestamp
# 10  2025-05-22T07:36:50.403Z 2025-05-22 13:06:54.056923
# 11  2025-05-22T07:36:50.403Z 2025-05-22 13:06:54.056923
# 12  2025-05-22T07:36:50.403Z 2025-05-22 13:06:54.056923
# 13  2025-05-22T07:36:50.403Z 2025-05-22 13:06:54.056923
# 14  2025-05-22T07:36:50.403Z 2025-05-22 13:06:54.056923
# 15  2025-05-22T07:36:50.403Z 2025-05-22 13:06:54.056923
# 16  2025-05-22T07:36:50.404Z 2025-05-22 13:06:54.056923
# 17  2025-05-22T07:36:50.404Z 2025-05-22 13:06:54.056923
# 18  2025-05-22T07:36:50.404Z 2025-05-22 13:06:54.056923
# 19  2025-05-22T07:36:50.404Z 2025-05-22 13:06:54.056923

# %%
# One thing I noticed was the scientific notation. I like it, but I want to be able to see the numbers in this case

pd.set_option("display.float_format", lambda x: "%.5f" % x)

# %%
df3 = df.groupby("name", sort=False)[
    [
        "quote.USD.percent_change_1h",
        "quote.USD.percent_change_24h",
        "quote.USD.percent_change_7d",
        "quote.USD.percent_change_30d",
        "quote.USD.percent_change_60d",
        "quote.USD.percent_change_90d",
    ]
].mean()
df3
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df3 = df.groupby("name", sort=False)[
#       2     [
#       3         "quote.USD.percent_change_1h",
#       4         "quote.USD.percent_change_24h",
#       5         "quote.USD.percent_change_7d",
#       6         "quote.USD.percent_change_30d",
#       7         "quote.USD.percent_change_60d",
#       8         "quote.USD.percent_change_90d",
#       9     ]
#      10 ].mean()
#      11 df3
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\groupby\generic.py:1964, in DataFrameGroupBy.__getitem__(self, key)
#    1957 if isinstance(key, tuple) and len(key) > 1:
#    1958     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1959     # valid syntax, so don't raise
#    1960     raise ValueError(
#    1961         "Cannot subset columns with a tuple with more than one element. "
#    1962         "Use a list instead."
#    1963     )
# -> 1964 return super().__getitem__(key)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\base.py:239, in SelectionMixin.__getitem__(self, key)
#     237     if len(self.obj.columns.intersection(key)) != len(set(key)):
#     238         bad_keys = list(set(key).difference(self.obj.columns))
# --> 239         raise KeyError(f"Columns not found: {str(bad_keys)[1:-1]}")
#     240     return self._gotitem(list(key), ndim=2)
#     242 else:
#
# KeyError: "Columns not found: 'quote.USD.percent_change_30d', 'quote.USD.percent_change_60d', 'quote.USD.percent_change_90d'"
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
