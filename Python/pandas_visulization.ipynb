# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("./Python/Dataset/Ice Cream Ratings.csv")
df = df.set_index("Date")

# %%
df.plot(
    kind="line",
    subplots=True,
    title="Ice Cream Ratings",
    xlabel="Daily Ratings",
    ylabel="Ratings",
)
# Out:
# array([<Axes: xlabel='Daily Ratings', ylabel='Ratings'>,
#        <Axes: xlabel='Daily Ratings', ylabel='Ratings'>,
#        <Axes: xlabel='Daily Ratings', ylabel='Ratings'>], dtype=object)

# %%
df
# Out:
#           Flavor Rating  Texture Rating  Overall Rating
# Date
# 1/1/2022       0.223090        0.040220        0.600129
# 1/2/2022       0.635886        0.938476        0.106264
# 1/3/2022       0.442323        0.044154        0.598112
# 1/4/2022       0.389128        0.549676        0.489353
# 1/5/2022       0.386887        0.519439        0.988280
# 1/6/2022       0.877984        0.193588        0.832827
# 1/7/2022       0.140995        0.325110        0.105147

# %%
 df.plot(
    kind="hist",bins = 20

)
# Out:
# <Axes: ylabel='Frequency'>

# %%
 df.plot(
    kind="box",grid = True
)
# Out:
# <Axes: >

# %%
 df.plot(
    kind="area"

)
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot.area()
# Out:
# <Axes: xlabel='Date'>

# %%
 df.plot(kind="pie", y= "Flavor Rating", figsize =(10, 10))
# Out:
# <Axes: ylabel='Flavor Rating'>
